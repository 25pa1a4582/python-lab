# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a4582/python-lab/blob/main/week1/program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PYTHON PROGRAM

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# a=2

# %%
print("2=4-4")
# Out:
# 2=4-4

# %% [markdown]
# Arthemetic operations in python
# 1.Addition +
# 2.Subtraction -
# 3.Multiplication *
# 4.normal division/ie a/b gives float value as quotient
# 5.floor division//ie a/b gives integer as quotient
# 6.modulo division % gives remainder
# 7.exponent)

# %%
a=int(input())
B=int(input())
Print
